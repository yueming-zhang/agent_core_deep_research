# %%
from bedrock_agentcore_starter_toolkit import Runtime
from boto3.session import Session
import boto3
import json
from pprint import pprint

boto_session = Session()
region = boto_session.region_name


agent_name = "deep_research_scoping_agent"
agent_core_client = boto3.client('bedrock-agentcore-control', region_name='us-west-2')

# %% [markdown]
# ## Update SSM Parameter store from .env

# %%
# Load .env file and create AWS Systems Manager secure parameters
from pathlib import Path
import dotenv

env_path = Path("/workspaces/agent_core_deep_research/.env")

if not env_path.exists():
    print(f"❌ .env file not found at {env_path}")
else:
    # Load environment variables
    env_vars = dotenv.dotenv_values(env_path)
    
    print(f"Found {len(env_vars)} environment variables in .env")
    
    # Create SSM client
    ssm_client = boto_session.client("ssm", region_name="us-west-2")
    
    # Create secure parameters for each key
    for key, value in env_vars.items():
        if not value or value.strip() == "":
            print(f"⚠️  Skipping empty value for {key}")
            continue
            
        parameter_name = f"/deep_research_scoping_agent/{key}"
        
        try:
            ssm_client.put_parameter(
                Name=parameter_name,
                Value=value,
                Type="SecureString",
                Overwrite=True,
                Description=f"Environment variable for deep_research_scoping_agent"
            )
            print(f"✅ Created/Updated secure parameter: {parameter_name}")
        except Exception as e:
            print(f"❌ Failed to create parameter {parameter_name}: {e}")
    
    print(f"\n✅ All environment variables stored as secure parameters in us-west-2")# Build Docker image and push to ECR

# %% [markdown]
# ## Build and Push Docker to ECR

# %%
import subprocess

# Get AWS account ID
account_id = boto_session.client("sts").get_caller_identity()["Account"]

# ECR repo URI
ecr_repo = f"{account_id}.dkr.ecr.{region}.amazonaws.com/{agent_name}"

# Create ECR repository if it doesn't exist
print(f"Creating ECR repository: {agent_name}...")
ecr_client = boto_session.client("ecr")
try:
    ecr_client.create_repository(
        repositoryName=agent_name,
        imageScanningConfiguration={'scanOnPush': True}
    )
    print(f"✅ ECR repository '{agent_name}' created successfully")
except ecr_client.exceptions.RepositoryAlreadyExistsException:
    print(f"ℹ️  ECR repository '{agent_name}' already exists")

# Authenticate Docker to ECR
print("Authenticating to ECR...")
login_password = subprocess.run(
    ["aws", "ecr", "get-login-password", "--region", region],
    capture_output=True,
    text=True,
    check=True
).stdout

subprocess.run(
    ["docker", "login", "--username", "AWS", "--password-stdin", f"{account_id}.dkr.ecr.{region}.amazonaws.com"],
    input=login_password,
    text=True,
    check=True
)

# Build Docker image (run from parent directory)
print(f"Building Docker image: {agent_name}...")
# subprocess.run(
#     ["docker", "build", "-f", "src/Dockerfile", "-t", agent_name, "."],
#     cwd="/workspaces/agent_core_deep_research",
#     check=True
# )

subprocess.run(
    ["docker", "build", "-t", agent_name, "."],
    check=True
)


# Tag Docker image
print(f"Tagging image for ECR: {ecr_repo}:latest...")
subprocess.run(
    ["docker", "tag", f"{agent_name}:latest", f"{ecr_repo}:latest"],
    check=True
)

# Push Docker image to ECR
print(f"Pushing image to ECR: {ecr_repo}:latest...")
subprocess.run(
    ["docker", "push", f"{ecr_repo}:latest"],
    check=True
)

print(f"✅ Docker image successfully pushed to {ecr_repo}:latest")

# %% [markdown]
# ## Create Memory

# %%
from bedrock_agentcore.memory import MemoryClient

memory_name = "DeepResearchAgent"
client = MemoryClient(region_name=region)
memory = client.create_or_get_memory(name=memory_name)
memory_id = memory['id']

# %% [markdown]
# ## Invoke by Boto3

# %%
#agent_name = "BasicAgentDemo_BasicAgent"
agent_name = "DeepResearchScopingAgent"
#agent_name = "deep_research_scoping_agent"
runtimeSessionId='dfmeoagmreaklgmrkleafremoigrmtesogmtrskhmtkrlshmt-g'  # Must be 33+ chars
thread_id='test-thread-35'

res = agent_core_client.list_agent_runtimes()
agent_id = [item['agentRuntimeId'] for item in res['agentRuntimes'] if item['agentRuntimeName']==agent_name][0]

res = agent_core_client.get_agent_runtime(agentRuntimeId=agent_id)
agentRuntimeArn = res['agentRuntimeArn']

agent_core_runtime_client = boto3.client('bedrock-agentcore')
payload = {
    "prompt": "I want to research the best coffee shops.",
    "thread_id": thread_id
}

# %%
response = agent_core_runtime_client.invoke_agent_runtime(
    agentRuntimeArn = agentRuntimeArn,
    runtimeSessionId=runtimeSessionId,
    payload=json.dumps(payload)
)

response_text = response['response'].read().decode('utf-8')
pprint(response_text)
# Out:
# ('{"messages": [{"content": "I want to research the best coffee shops.", '
#  '"additional_kwargs": {}, "response_metadata": {}, "type": "human", "name": '
#  'null, "id": "3897d579-7882-419e-91aa-4b68d9fd509f"}, {"content": "Could you '
#  'please specify the location or city where you want to research the best '
#  'coffee shops?", "additional_kwargs": {}, "response_metadata": {}, "type": '
#  '"ai", "name": null, "id": "49f2027a-f9db-4150-9647-13bfea084e53", '
#  '"tool_calls": [], "invalid_tool_calls": [], "usage_metadata": null}], '
#  '"supervisor_messages": [], "raw_notes": [], "notes": []}')

# %%
json_res = json.loads(response_text)
pprint(json_res['messages'][-1]['content'])
# Out:
# ('Could you please specify the location or city where you want to research the '
#  'best coffee shops?')

# %%
payload1 = {
    "prompt": "Let's focus on Coffee quality in Seattle",
    "thread_id": thread_id
}

response = agent_core_runtime_client.invoke_agent_runtime(
    agentRuntimeArn = agentRuntimeArn,
    runtimeSessionId=runtimeSessionId,
    payload=json.dumps(payload1)
)

response_text = response['response'].read().decode('utf-8')
json_res = json.loads(response_text)
pprint(json_res)
# Out:
# {'messages': [{'additional_kwargs': {},
#                'content': 'I want to research the best coffee shops.',
#                'id': '3897d579-7882-419e-91aa-4b68d9fd509f',
#                'name': None,
#                'response_metadata': {},
#                'type': 'human'},
#               {'additional_kwargs': {},
#                'content': 'Could you please specify the location or city where '
#                           'you want to research the best coffee shops?',
#                'id': '49f2027a-f9db-4150-9647-13bfea084e53',
#                'invalid_tool_calls': [],
#                'name': None,
#                'response_metadata': {},
#                'tool_calls': [],
#                'type': 'ai',
#                'usage_metadata': None},
#               {'additional_kwargs': {},
#                'content': "Let's focus on Coffee quality in Seattle",
#                'id': '2fe18379-87cd-42d3-8eab-162207d02d0d',
#                'name': None,
#                'response_metadata': {},
#                'type': 'human'},
#               {'additional_kwargs': {},
#                'content': 'Thank you for specifying that you want to research '
#                           'the best coffee shops in Seattle, focusing on '
#                           'coffee quality. I have sufficient information to '
#                           'proceed and will now begin researching top coffee '
#                           'shops in Seattle based on their coffee quality.',
#                'id': '4647d134-841a-41e4-a2e3-2641931859e2',
#                'invalid_tool_calls': [],
#                'name': None,
#                'response_metadata': {},
#                'tool_calls': [],
#                'type': 'ai',
#                'usage_metadata': None}],
#  'notes': [],
#  'raw_notes': [],
#  'research_brief': 'I want to research the best coffee shops in Seattle, with '
#                    'a primary focus on coffee quality. Specifically, I am '
#                    'interested in evaluating factors such as bean sourcing, '
#                    'roasting methods, brewing techniques, and taste as they '
#                    'relate to coffee quality. Other aspects such as ambiance, '
#                    'price, or food offerings have not been specified and '
#                    'should be considered flexible unless further preferences '
#                    'are provided. Please prioritize information from official '
#                    'coffee shop websites, reputable specialty coffee '
#                    'publications, and user reviews from primary platforms '
#                    '(such as Google Reviews or Yelp) when available.',
#  'supervisor_messages': [{'additional_kwargs': {},
#                           'content': 'I want to research the best coffee shops '
#                                      'in Seattle, with a primary focus on '
#                                      'coffee quality. Specifically, I am '
#                                      'interested in evaluating factors such as '
#                                      'bean sourcing, roasting methods, brewing '
#                                      'techniques, and taste as they relate to '
#                                      'coffee quality. Other aspects such as '
#                                      'ambiance, price, or food offerings have '
#                                      'not been specified and should be '
#                                      'considered flexible unless further '
#                                      'preferences are provided. Please '
#                                      'prioritize information from official '
#                                      'coffee shop websites, reputable '
#                                      'specialty coffee publications, and user '
#                                      'reviews from primary platforms (such as '
#                                      'Google Reviews or Yelp) when available..',
#                           'id': '050134cc-9201-40ab-8e41-6e50b97ea53d',
#                           'name': None,
#                           'response_metadata': {},
#                           'type': 'human'}]}

# %%
payload2 = {
    "prompt": "Let's focus on coffee bean origin and processing methods",
    "thread_id": "test-thread-2"
}

response = agent_core_runtime_client.invoke_agent_runtime(
    agentRuntimeArn = agentRuntimeArn,
    payload=json.dumps(payload2)
)

response_text = response['response'].read().decode('utf-8')
json_res = json.loads(response_text)
pprint(json_res)
# Out:
# {'messages': [{'additional_kwargs': {},
#                'content': "Let's focus on coffee bean origin and processing "
#                           'methods',
#                'id': '64630a73-9331-4385-88d0-39d08a21c36f',
#                'name': None,
#                'response_metadata': {},
#                'type': 'human'},
#               {'additional_kwargs': {},
#                'content': 'Thank you for specifying that you would like the '
#                           'report to focus on coffee bean origin and '
#                           'processing methods. I understand that the scope '
#                           'should cover where coffee beans come from and the '
#                           'various methods used to process them. I will now '
#                           'begin the research based on this information.',
#                'id': '7370d95c-a1d7-45f9-bd0c-b2b92f4719a1',
#                'invalid_tool_calls': [],
#                'name': None,
#                'response_metadata': {},
#                'tool_calls': [],
#                'type': 'ai',
#                'usage_metadata': None}],
#  'notes': [],
#  'raw_notes': [],
#  'research_brief': 'I want to research the origins of coffee beans (including '
#                    'the countries and regions where they are grown) and the '
#                    'various processing methods used after harvesting (such as '
#                    'washed, natural, honey, and any other significant '
#                    'methods). Please provide detailed information on how '
#                    'origin and processing methods influence the '
#                    'characteristics of the coffee beans, such as flavor '
#                    'profile, quality, and other notable attributes. No '
#                    'specific preferences regarding price, sustainability, or '
#                    'certification have been stated, so consider all relevant '
#                    'information unless otherwise specified. Prioritize '
#                    'information from official coffee industry sources, '
#                    'reputable coffee organizations, and primary research '
#                    'articles where possible.',
#  'supervisor_messages': [{'additional_kwargs': {},
#                           'content': 'I want to research the origins of coffee '
#                                      'beans (including the countries and '
#                                      'regions where they are grown) and the '
#                                      'various processing methods used after '
#                                      'harvesting (such as washed, natural, '
#                                      'honey, and any other significant '
#                                      'methods). Please provide detailed '
#                                      'information on how origin and processing '
#                                      'methods influence the characteristics of '
#                                      'the coffee beans, such as flavor '
#                                      'profile, quality, and other notable '
#                                      'attributes. No specific preferences '
#                                      'regarding price, sustainability, or '
#                                      'certification have been stated, so '
#                                      'consider all relevant information unless '
#                                      'otherwise specified. Prioritize '
#                                      'information from official coffee '
#                                      'industry sources, reputable coffee '
#                                      'organizations, and primary research '
#                                      'articles where possible..',
#                           'id': 'f0b7c13b-f67d-4538-966e-7016cd17d372',
#                           'name': None,
#                           'response_metadata': {},
#                           'type': 'human'}]}

# %% [markdown]
# ## Read from Memory

# %%
import boto3
import json
from botocore.exceptions import ClientError

def list_events_with_payloads(
    memory_id: str,
    actor_id: str,
    session_id: str,   # <- your LangGraph thread_id
    *,
    region: str = "us-west-2",
    max_results: int = 50,
    limit_events: int | None = 200,
):
    ac = boto3.client("bedrock-agentcore", region_name=region)
    kwargs = {
        "memoryId": memory_id,
        "actorId": actor_id,
        "sessionId": session_id,
        "includePayloads": True,
        "maxResults": max_results,
    }
    res = ac.list_events(**kwargs)
    return res

MEMORY_ID = "DeepResearchAgent-7gZmvrCKCl"
ACTOR_ID  = "default_actor"      # your LangGraph 'actor_id'
THREAD_ID = "test-thread-1"   # your LangGraph 'thread_id'

res = list_events_with_payloads(MEMORY_ID, ACTOR_ID, THREAD_ID, region="us-west-2")
pprint(res)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '178123',
#                                       'content-type': 'application/json',
#                                       'date': 'Wed, 12 Nov 2025 20:48:43 GMT',
#                                       'x-amzn-requestid': '0fc2f630-3d7c-4eb6-8ef0-0d9b114c2016'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '0fc2f630-3d7c-4eb6-8ef0-0d9b114c2016',
#                       'RetryAttempts': 0},
#  'events': [{'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980463957#e6aa20bb',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 47, 43, 957000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:write_research_brief", '
#                                   '"version": '
#                                   '"00000000000000000000000000000027.0.07333667061455673", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"research_brief", "version": '
#                                   '"00000000000000000000000000000027.0.07333667061455673", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"supervisor_messages", "version": '
#                                   '"00000000000000000000000000000027.0.07333667061455673", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0c008d-6815-6cb2-8019-992ace929da0", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwGadwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0c008d-44bf-67a1-8018-a394cf3c6863", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980463956#9d83dce8',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 47, 43, 956000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0c008d-44bf-67a1-8018-a394cf3c6863", '
#                                   '"writes": [{"task_id": '
#                                   '"a90349e5-53db-e62e-1ef2-f21b43c144d7", '
#                                   '"channel": "research_brief", "value": '
#                                   '{"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'write_research_brief"}, {"task_id": '
#                                   '"a90349e5-53db-e62e-1ef2-f21b43c144d7", '
#                                   '"channel": "supervisor_messages", "value": '
#                                   '{"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'write_research_brief"}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980460256#51a27ad5',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 47, 40, 256000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"messages", "version": '
#                                   '"00000000000000000000000000000026.0.9008459831235096", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:clarify_with_user", "version": '
#                                   '"00000000000000000000000000000026.0.9008459831235096", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:write_research_brief", '
#                                   '"version": '
#                                   '"00000000000000000000000000000026.0.9008459831235096", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": "", "value": {"type": '
#                                   '"null", "data": ""}}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0c008d-44bf-67a1-8018-a394cf3c6863", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwGKdwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0c008d-306f-6a8f-8017-8a3a2aeac3dd", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980460254#0ad9ef10',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 47, 40, 254000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0c008d-306f-6a8f-8017-8a3a2aeac3dd", '
#                                   '"writes": [{"task_id": '
#                                   '"407344af-af82-2401-8afe-78e08e4ec824", '
#                                   '"channel": "messages", "value": {"type": '
#                                   '"msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'clarify_with_user"}, {"task_id": '
#                                   '"407344af-af82-2401-8afe-78e08e4ec824", '
#                                   '"channel": '
#                                   '"branch:to:write_research_brief", '
#                                   '"task_path": "~__pregel_pull, '
#                                   'clarify_with_user", "value": {"type": '
#                                   '"null", "data": ""}}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980458234#1d6849d4',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 47, 38, 234000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"__start__", "version": '
#                                   '"00000000000000000000000000000025.0.17502930535884365", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"messages", "version": '
#                                   '"00000000000000000000000000000025.0.17502930535884365", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:clarify_with_user", "version": '
#                                   '"00000000000000000000000000000025.0.17502930535884365", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": "", "value": {"type": '
#                                   '"null", "data": ""}}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0c008d-306f-6a8f-8017-8a3a2aeac3dd", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwF6dwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0c008d-3068-6a77-8016-08554e2aa7d7", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980458119#0eac5a1b',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 47, 38, 119000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0c008d-3068-6a77-8016-08554e2aa7d7", '
#                                   '"writes": [{"task_id": '
#                                   '"955b8087-1cc5-2efe-aca4-b612c8dd28d6", '
#                                   '"channel": "messages", "value": {"type": '
#                                   '"msgpack", "data": '
#                                   '"kcemBZS9bGFuZ2NoYWluX2NvcmUubWVzc2FnZXMuaHVtYW6sSHVtYW5NZXNzYWdlhqdjb250ZW502SBwbGVzZSBmb2N1cyBvbiBjb2ZmZWUgaW4gc2VhdHRsZbFhZGRpdGlvbmFsX2t3YXJnc4CxcmVzcG9uc2VfbWV0YWRhdGGApHR5cGWlaHVtYW6kbmFtZcCiaWTAs21vZGVsX3ZhbGlkYXRlX2pzb24="}, '
#                                   '"task_path": "~__pregel_pull, __start__"}, '
#                                   '{"task_id": '
#                                   '"955b8087-1cc5-2efe-aca4-b612c8dd28d6", '
#                                   '"channel": "branch:to:clarify_with_user", '
#                                   '"task_path": "~__pregel_pull, __start__", '
#                                   '"value": {"type": "null", "data": ""}}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980458118#d507c45c',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 47, 38, 118000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"__start__", "version": '
#                                   '"00000000000000000000000000000024.0.12107346222125648", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"gahtZXNzYWdlc5HHpgWUvWxhbmdjaGFpbl9jb3JlLm1lc3NhZ2VzLmh1bWFurEh1bWFuTWVzc2FnZYanY29udGVudNkgcGxlc2UgZm9jdXMgb24gY29mZmVlIGluIHNlYXR0bGWxYWRkaXRpb25hbF9rd2FyZ3OAsXJlc3BvbnNlX21ldGFkYXRhgKR0eXBlpWh1bWFupG5hbWXAomlkwLNtb2RlbF92YWxpZGF0ZV9qc29u"}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0c008d-3068-6a77-8016-08554e2aa7d7", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WlaW5wdXSkc3RlcBancGFyZW50c4CoYWN0b3JfaWStZGVmYXVsdF9hY3Rvcg=="}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0c008b-90f8-6f2b-8015-9c991a40cc54", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980414557#11ffd001',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 46, 54, 557000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:write_research_brief", '
#                                   '"version": '
#                                   '"00000000000000000000000000000023.0.7753960959749892", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"research_brief", "version": '
#                                   '"00000000000000000000000000000023.0.7753960959749892", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"supervisor_messages", "version": '
#                                   '"00000000000000000000000000000023.0.7753960959749892", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0c008b-90f8-6f2b-8015-9c991a40cc54", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwFadwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0c008b-6c3a-6951-8014-f6e6a46edbfd", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980414556#7450d821',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 46, 54, 556000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0c008b-6c3a-6951-8014-f6e6a46edbfd", '
#                                   '"writes": [{"task_id": '
#                                   '"add330bc-6f42-e4b5-564c-aeedb552aaf8", '
#                                   '"channel": "research_brief", "value": '
#                                   '{"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'write_research_brief"}, {"task_id": '
#                                   '"add330bc-6f42-e4b5-564c-aeedb552aaf8", '
#                                   '"channel": "supervisor_messages", "value": '
#                                   '{"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'write_research_brief"}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980410708#3467b972',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 46, 50, 708000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"messages", "version": '
#                                   '"00000000000000000000000000000022.0.03451633731569781", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:clarify_with_user", "version": '
#                                   '"00000000000000000000000000000022.0.03451633731569781", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:write_research_brief", '
#                                   '"version": '
#                                   '"00000000000000000000000000000022.0.03451633731569781", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": "", "value": {"type": '
#                                   '"null", "data": ""}}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0c008b-6c3a-6951-8014-f6e6a46edbfd", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwFKdwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0c008b-598e-64e4-8013-99f77e0141f4", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980410707#ac092928',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 46, 50, 707000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0c008b-598e-64e4-8013-99f77e0141f4", '
#                                   '"writes": [{"task_id": '
#                                   '"61bc15fd-fcec-432a-6d3e-3219844e36ef", '
#                                   '"channel": "messages", "value": {"type": '
#                                   '"msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'clarify_with_user"}, {"task_id": '
#                                   '"61bc15fd-fcec-432a-6d3e-3219844e36ef", '
#                                   '"channel": '
#                                   '"branch:to:write_research_brief", '
#                                   '"task_path": "~__pregel_pull, '
#                                   'clarify_with_user", "value": {"type": '
#                                   '"null", "data": ""}}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980408892#56a8745d',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 46, 48, 892000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"__start__", "version": '
#                                   '"00000000000000000000000000000021.0.09456758315443736", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"messages", "version": '
#                                   '"00000000000000000000000000000021.0.09456758315443736", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:clarify_with_user", "version": '
#                                   '"00000000000000000000000000000021.0.09456758315443736", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": "", "value": {"type": '
#                                   '"null", "data": ""}}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0c008b-598e-64e4-8013-99f77e0141f4", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwE6dwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0c008b-5985-6401-8012-6e36ad42ef4e", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980408744#6ad10a02',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 46, 48, 744000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0c008b-5985-6401-8012-6e36ad42ef4e", '
#                                   '"writes": [{"task_id": '
#                                   '"a22a7ec9-96d9-310a-05f4-0cb96e03b89e", '
#                                   '"channel": "messages", "value": {"type": '
#                                   '"msgpack", "data": '
#                                   '"kceiBZS9bGFuZ2NoYWluX2NvcmUubWVzc2FnZXMuaHVtYW6sSHVtYW5NZXNzYWdlhqdjb250ZW50vWNhbiB5b3UgcmVzZWFyY2ggYmVzdCBjb2ZmZWUusWFkZGl0aW9uYWxfa3dhcmdzgLFyZXNwb25zZV9tZXRhZGF0YYCkdHlwZaVodW1hbqRuYW1lwKJpZMCzbW9kZWxfdmFsaWRhdGVfanNvbg=="}, '
#                                   '"task_path": "~__pregel_pull, __start__"}, '
#                                   '{"task_id": '
#                                   '"a22a7ec9-96d9-310a-05f4-0cb96e03b89e", '
#                                   '"channel": "branch:to:clarify_with_user", '
#                                   '"task_path": "~__pregel_pull, __start__", '
#                                   '"value": {"type": "null", "data": ""}}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762980408741#70bf2b8c',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 20, 46, 48, 741000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"__start__", "version": '
#                                   '"00000000000000000000000000000020.0.08996551081676785", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"gahtZXNzYWdlc5HHogWUvWxhbmdjaGFpbl9jb3JlLm1lc3NhZ2VzLmh1bWFurEh1bWFuTWVzc2FnZYanY29udGVudL1jYW4geW91IHJlc2VhcmNoIGJlc3QgY29mZmVlLrFhZGRpdGlvbmFsX2t3YXJnc4CxcmVzcG9uc2VfbWV0YWRhdGGApHR5cGWlaHVtYW6kbmFtZcCiaWTAs21vZGVsX3ZhbGlkYXRlX2pzb24="}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0c008b-5985-6401-8012-6e36ad42ef4e", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WlaW5wdXSkc3RlcBKncGFyZW50c4CoYWN0b3JfaWStZGVmYXVsdF9hY3Rvcg=="}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0bfee0-1d2b-6523-8011-89194e5e0a53", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968940220#5c91dc9d',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 35, 40, 220000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:write_research_brief", '
#                                   '"version": '
#                                   '"00000000000000000000000000000019.0.4860437154403633", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"research_brief", "version": '
#                                   '"00000000000000000000000000000019.0.4860437154403633", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"supervisor_messages", "version": '
#                                   '"00000000000000000000000000000019.0.4860437154403633", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0bfee0-1d2b-6523-8011-89194e5e0a53", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwEadwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0bfedf-f8dc-6f64-8010-12f067b444db", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968940219#b02d38ee',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 35, 40, 219000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0bfedf-f8dc-6f64-8010-12f067b444db", '
#                                   '"writes": [{"task_id": '
#                                   '"c6a0b60b-5455-d812-00e1-95d967dcd4ea", '
#                                   '"channel": "research_brief", "value": '
#                                   '{"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'write_research_brief"}, {"task_id": '
#                                   '"c6a0b60b-5455-d812-00e1-95d967dcd4ea", '
#                                   '"channel": "supervisor_messages", "value": '
#                                   '{"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'write_research_brief"}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968936416#a7ba12f6',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 35, 36, 416000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"messages", "version": '
#                                   '"00000000000000000000000000000018.0.34297340290672784", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:clarify_with_user", "version": '
#                                   '"00000000000000000000000000000018.0.34297340290672784", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:write_research_brief", '
#                                   '"version": '
#                                   '"00000000000000000000000000000018.0.34297340290672784", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": "", "value": {"type": '
#                                   '"null", "data": ""}}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0bfedf-f8dc-6f64-8010-12f067b444db", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwEKdwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0bfedf-f0cb-6ad3-800f-c3a4ac7fadbf", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968936416#8a67cff5',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 35, 36, 416000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0bfedf-f0cb-6ad3-800f-c3a4ac7fadbf", '
#                                   '"writes": [{"task_id": '
#                                   '"d4b2609c-c20e-f0dc-546f-736a2f630f2d", '
#                                   '"channel": "messages", "value": {"type": '
#                                   '"msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'clarify_with_user"}, {"task_id": '
#                                   '"d4b2609c-c20e-f0dc-546f-736a2f630f2d", '
#                                   '"channel": '
#                                   '"branch:to:write_research_brief", '
#                                   '"task_path": "~__pregel_pull, '
#                                   'clarify_with_user", "value": {"type": '
#                                   '"null", "data": ""}}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968935693#1ba070ea',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 35, 35, 693000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"__start__", "version": '
#                                   '"00000000000000000000000000000017.0.305403443038748", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"messages", "version": '
#                                   '"00000000000000000000000000000017.0.305403443038748", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:clarify_with_user", "version": '
#                                   '"00000000000000000000000000000017.0.305403443038748", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": "", "value": {"type": '
#                                   '"null", "data": ""}}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0bfedf-f0cb-6ad3-800f-c3a4ac7fadbf", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwD6dwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0bfedf-f0c4-6011-800e-7ca69f4f718b", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968935565#d9f38d9d',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 35, 35, 565000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0bfedf-f0c4-6011-800e-7ca69f4f718b", '
#                                   '"writes": [{"task_id": '
#                                   '"43853dcd-6310-08ae-40e0-93bca548dd62", '
#                                   '"channel": "messages", "value": {"type": '
#                                   '"msgpack", "data": '
#                                   '"kceiBZS9bGFuZ2NoYWluX2NvcmUubWVzc2FnZXMuaHVtYW6sSHVtYW5NZXNzYWdlhqdjb250ZW50vWNhbiB5b3UgcmVzZWFyY2ggYmVzdCBjb2ZmZWUusWFkZGl0aW9uYWxfa3dhcmdzgLFyZXNwb25zZV9tZXRhZGF0YYCkdHlwZaVodW1hbqRuYW1lwKJpZMCzbW9kZWxfdmFsaWRhdGVfanNvbg=="}, '
#                                   '"task_path": "~__pregel_pull, __start__"}, '
#                                   '{"task_id": '
#                                   '"43853dcd-6310-08ae-40e0-93bca548dd62", '
#                                   '"channel": "branch:to:clarify_with_user", '
#                                   '"task_path": "~__pregel_pull, __start__", '
#                                   '"value": {"type": "null", "data": ""}}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968935563#4184e554',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 35, 35, 563000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"__start__", "version": '
#                                   '"00000000000000000000000000000016.0.9454452862824004", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"gahtZXNzYWdlc5HHogWUvWxhbmdjaGFpbl9jb3JlLm1lc3NhZ2VzLmh1bWFurEh1bWFuTWVzc2FnZYanY29udGVudL1jYW4geW91IHJlc2VhcmNoIGJlc3QgY29mZmVlLrFhZGRpdGlvbmFsX2t3YXJnc4CxcmVzcG9uc2VfbWV0YWRhdGGApHR5cGWlaHVtYW6kbmFtZcCiaWTAs21vZGVsX3ZhbGlkYXRlX2pzb24="}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0bfedf-f0c4-6011-800e-7ca69f4f718b", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WlaW5wdXSkc3RlcA6ncGFyZW50c4CoYWN0b3JfaWStZGVmYXVsdF9hY3Rvcg=="}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0bfedb-b559-691b-800d-fd4fb3957471", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968821960#f4afae79',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 33, 41, 960000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:write_research_brief", '
#                                   '"version": '
#                                   '"00000000000000000000000000000015.0.35619584386803715", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"research_brief", "version": '
#                                   '"00000000000000000000000000000015.0.35619584386803715", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"supervisor_messages", "version": '
#                                   '"00000000000000000000000000000015.0.35619584386803715", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0bfedb-b559-691b-800d-fd4fb3957471", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwDadwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0bfedb-9f73-69fa-800c-7e4f11419561", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968821959#9ca08f22',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 33, 41, 959000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0bfedb-9f73-69fa-800c-7e4f11419561", '
#                                   '"writes": [{"task_id": '
#                                   '"97a4dbf0-8f24-d37d-8be1-26ac1f2f5820", '
#                                   '"channel": "research_brief", "value": '
#                                   '{"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'write_research_brief"}, {"task_id": '
#                                   '"97a4dbf0-8f24-d37d-8be1-26ac1f2f5820", '
#                                   '"channel": "supervisor_messages", "value": '
#                                   '{"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'write_research_brief"}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968819666#4f1f8c78',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 33, 39, 666000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"messages", "version": '
#                                   '"00000000000000000000000000000014.0.4780095816270692", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:clarify_with_user", "version": '
#                                   '"00000000000000000000000000000014.0.4780095816270692", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:write_research_brief", '
#                                   '"version": '
#                                   '"00000000000000000000000000000014.0.4780095816270692", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": "", "value": {"type": '
#                                   '"null", "data": ""}}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0bfedb-9f73-69fa-800c-7e4f11419561", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwDKdwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0bfedb-9057-6637-800b-958671d7e1d9", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968819663#15aac3d4',
# ...
#                                   '"1f0bfed3-704a-61e4-8003-856854618b21", '
#                                   '"writes": [{"task_id": '
#                                   '"1e67038f-f5cb-1bd1-0b0f-d108c9b17606", '
#                                   '"channel": "messages", "value": {"type": '
#                                   '"msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'clarify_with_user"}, {"task_id": '
#                                   '"1e67038f-f5cb-1bd1-0b0f-d108c9b17606", '
#                                   '"channel": '
#                                   '"branch:to:write_research_brief", '
#                                   '"task_path": "~__pregel_pull, '
#                                   'clarify_with_user", "value": {"type": '
#                                   '"null", "data": ""}}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968600103#ea9b8a2e',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 30, 0, 103000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"__start__", "version": '
#                                   '"00000000000000000000000000000005.0.8613593881463248", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"messages", "version": '
#                                   '"00000000000000000000000000000005.0.8613593881463248", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:clarify_with_user", "version": '
#                                   '"00000000000000000000000000000005.0.8613593881463248", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": "", "value": {"type": '
#                                   '"null", "data": ""}}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0bfed3-704a-61e4-8003-856854618b21", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwA6dwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0bfed3-7043-6ee5-8002-7ff6aa1972cf", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968599968#60239cc9',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 29, 59, 968000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0bfed3-7043-6ee5-8002-7ff6aa1972cf", '
#                                   '"writes": [{"task_id": '
#                                   '"9c9784f6-bbb1-ee32-27db-2f518c4f6195", '
#                                   '"channel": "messages", "value": {"type": '
#                                   '"msgpack", "data": '
#                                   '"kcemBZS9bGFuZ2NoYWluX2NvcmUubWVzc2FnZXMuaHVtYW6sSHVtYW5NZXNzYWdlhqdjb250ZW502SBwbGVzZSBmb2N1cyBvbiBjb2ZmZWUgaW4gc2VhdHRsZbFhZGRpdGlvbmFsX2t3YXJnc4CxcmVzcG9uc2VfbWV0YWRhdGGApHR5cGWlaHVtYW6kbmFtZcCiaWTAs21vZGVsX3ZhbGlkYXRlX2pzb24="}, '
#                                   '"task_path": "~__pregel_pull, __start__"}, '
#                                   '{"task_id": '
#                                   '"9c9784f6-bbb1-ee32-27db-2f518c4f6195", '
#                                   '"channel": "branch:to:clarify_with_user", '
#                                   '"task_path": "~__pregel_pull, __start__", '
#                                   '"value": {"type": "null", "data": ""}}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968599966#c99445af',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 29, 59, 966000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"__start__", "version": '
#                                   '"00000000000000000000000000000004.0.7613604290499357", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"gahtZXNzYWdlc5HHpgWUvWxhbmdjaGFpbl9jb3JlLm1lc3NhZ2VzLmh1bWFurEh1bWFuTWVzc2FnZYanY29udGVudNkgcGxlc2UgZm9jdXMgb24gY29mZmVlIGluIHNlYXR0bGWxYWRkaXRpb25hbF9rd2FyZ3OAsXJlc3BvbnNlX21ldGFkYXRhgKR0eXBlpWh1bWFupG5hbWXAomlkwLNtb2RlbF92YWxpZGF0ZV9qc29u"}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0bfed3-7043-6ee5-8002-7ff6aa1972cf", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WlaW5wdXSkc3RlcAKncGFyZW50c4CoYWN0b3JfaWStZGVmYXVsdF9hY3Rvcg=="}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0bfed2-5b08-6343-8001-6f6ed35c23bb", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968570897#8bc7ccf0',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 29, 30, 897000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"messages", "version": '
#                                   '"00000000000000000000000000000003.0.8970824804289231", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"..."}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:clarify_with_user", "version": '
#                                   '"00000000000000000000000000000003.0.8970824804289231", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0bfed2-5b08-6343-8001-6f6ed35c23bb", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwAadwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0bfed2-39b1-634f-8000-f2e46ae55d1a", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968570896#02547c0d',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 29, 30, 896000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0bfed2-39b1-634f-8000-f2e46ae55d1a", '
#                                   '"writes": [{"task_id": '
#                                   '"4baf160c-a158-beda-23c9-0b52f3c3d6b3", '
#                                   '"channel": "messages", "value": {"type": '
#                                   '"msgpack", "data": '
#                                   '"..."}, '
#                                   '"task_path": "~__pregel_pull, '
#                                   'clarify_with_user"}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968567537#7bd68afb',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 29, 27, 537000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"__start__", "version": '
#                                   '"00000000000000000000000000000002.0.09911746747860783", '
#                                   '"value": "_empty", "thread_id": '
#                                   '"test-thread-1", "checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"messages", "version": '
#                                   '"00000000000000000000000000000002.0.09911746747860783", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '""}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "channel_data", "channel": '
#                                   '"branch:to:clarify_with_user", "version": '
#                                   '"00000000000000000000000000000002.0.09911746747860783", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": "", "value": {"type": '
#                                   '"null", "data": ""}}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0bfed2-39b1-634f-8000-f2e46ae55d1a", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '"..."}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WkbG9vcKRzdGVwAKdwYXJlbnRzgKhhY3Rvcl9pZK1kZWZhdWx0X2FjdG9y"}, '
#                                   '"parent_checkpoint_id": '
#                                   '"1f0bfed2-39ab-639b-bfff-8a0fa52d8cb5", '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968567399#393837f3',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 29, 27, 399000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "writes", "checkpoint_id": '
#                                   '"1f0bfed2-39ab-639b-bfff-8a0fa52d8cb5", '
#                                   '"writes": [{"task_id": '
#                                   '"07b76d8b-e3c9-596b-6471-a14a0bdfecdd", '
#                                   '"channel": "messages", "value": {"type": '
#                                   '"msgpack", "data": '
#                                   '"kceiBZS9bGFuZ2NoYWluX2NvcmUubWVzc2FnZXMuaHVtYW6sSHVtYW5NZXNzYWdlhqdjb250ZW50vWNhbiB5b3UgcmVzZWFyY2ggYmVzdCBjb2ZmZWUusWFkZGl0aW9uYWxfa3dhcmdzgLFyZXNwb25zZV9tZXRhZGF0YYCkdHlwZaVodW1hbqRuYW1lwKJpZMCzbW9kZWxfdmFsaWRhdGVfanNvbg=="}, '
#                                   '"task_path": "~__pregel_pull, __start__"}, '
#                                   '{"task_id": '
#                                   '"07b76d8b-e3c9-596b-6471-a14a0bdfecdd", '
#                                   '"channel": "branch:to:clarify_with_user", '
#                                   '"task_path": "~__pregel_pull, __start__", '
#                                   '"value": {"type": "null", "data": ""}}]}'}],
#              'sessionId': 'test-thread-1'},
#             {'actorId': 'default_actor',
#              'branch': {'name': 'main'},
#              'eventId': '0000001762968567398#ac7775a0',
#              'eventTimestamp': datetime.datetime(2025, 11, 12, 17, 29, 27, 398000, tzinfo=tzlocal()),
#              'memoryId': 'DeepResearchAgent-7gZmvrCKCl',
#              'payload': [{'blob': '{"event_type": "channel_data", "channel": '
#                                   '"__start__", "version": '
#                                   '"00000000000000000000000000000001.0.3799784879778705", '
#                                   '"value": {"type": "msgpack", "data": '
#                                   '"gahtZXNzYWdlc5HHogWUvWxhbmdjaGFpbl9jb3JlLm1lc3NhZ2VzLmh1bWFurEh1bWFuTWVzc2FnZYanY29udGVudL1jYW4geW91IHJlc2VhcmNoIGJlc3QgY29mZmVlLrFhZGRpdGlvbmFsX2t3YXJnc4CxcmVzcG9uc2VfbWV0YWRhdGGApHR5cGWlaHVtYW6kbmFtZcCiaWTAs21vZGVsX3ZhbGlkYXRlX2pzb24="}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'},
#                          {'blob': '{"event_type": "checkpoint", '
#                                   '"checkpoint_id": '
#                                   '"1f0bfed2-39ab-639b-bfff-8a0fa52d8cb5", '
#                                   '"checkpoint_data": {"type": "msgpack", '
#                                   '"data": '
#                                   '""}, '
#                                   '"metadata": {"type": "msgpack", "data": '
#                                   '"hKZzb3VyY2WlaW5wdXSkc3RlcP+ncGFyZW50c4CoYWN0b3JfaWStZGVmYXVsdF9hY3Rvcg=="}, '
#                                   '"thread_id": "test-thread-1", '
#                                   '"checkpoint_ns": ""}'}],
#              'sessionId': 'test-thread-1'}]}
